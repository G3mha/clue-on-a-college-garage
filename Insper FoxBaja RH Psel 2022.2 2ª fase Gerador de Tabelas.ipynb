# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
print(f'Esperamos trabalhar no diretório: \n{os.getcwd()}\n')
# Out:
# Esperamos trabalhar no diretório:
# /Users/enriccogemha/Dropbox/Insper/Insper FoxBaja/Insper FoxBaja 2022/Insper FoxBaja RH PSel 2022.2

# %%
valor_compras = [] # done
subssistemas_compras = [] # done
modo_compras = [] # done
quantidade_compras = [] # done
tipo_produto_compras = [] # done
codigo_compras = [] # done

for i in range(100):
    
    valor = float(f'{random.randint(1, 200)}.{random.randint(10,99)}')
    valor_compras.append(valor)

    qnt = random.randint(1, 3)
    quantidade_compras.append(qnt)

    modo = random.choice(['Qualquer fornecedor', 'Fornecedor específico'])
    modo_compras.append(modo)

    # não parafusos
    binario = random.choice([1,2])
    if binario == 1:
        sub_projetos = random.choice(['Eletrônica', 'Simulação', 'Freio', 'Suspensão e Direção', 'Motor e Transmissão'])
        subssistemas_compras.append(sub_projetos)

        codigos = ['NM1029.1', 'N9.10MF', 'K930KL1.1', 'R7HT.1', 'DFSA0DF.5', 'DSD94455', 'DASIDJE3.3', '12321SJKJ', '2LMSOAMSI.1', 'XO0WE2M.2', '1203.12234', 'ASDW343.12', 'KASDI0.1', 'QWE.01231A', 'ASDKL.1023', 'PB9BF0.S1', 'LL123.492', 'DSA.1120', 'KLA1D.AS1']
        codigo_escolhido = random.choice(codigos)
        codigo_compras.append(codigo_escolhido)
        index = codigos.index(codigo_escolhido)

        tipos = ['ABRACADEIRA DE NYLON 3.6 X 200 BRANCA', 'ABRACADEIRA DE NYLON 4.8 X 200 T50R', 'Cordão O-ring espaguete de vedação de borracha de 10m', 'Tela metálica inoxidável malha 3mm,	fio1.6mm', 'Martelo com ponta de borracha', 'Cubo V3 Usinado', 'Sensor de temperatura DS18B20 à prova dagua - o modelo não deve divergir do link de referência', 'Modulo RF LORA - 433MHz - Módulo Wifi LoRa E32-TTL-100 NÃO PODE DIVERGIR DO MODELO DE REFERÊNCIA', 'Circuito integrado 74HC595 DIP - Shift Register -  NÃO COMPRAR SMD', 'Placa de fibra de vidro virgem cobread 20cm x 20cm', 'Óculos SAE SF300', 'Extintor capacidade extintora 1-A, 5-B, C de massa 1kg', 'Restritor de braço com especificação SFI 3.3', 'Saco Zip Lock 24 x 17 - N8', 'Manta silicone 3mm', 'Óleo para transmissão SAE 80W90 Motul/Lubrax/Mobil', 'Mangueira Aeroquip com Malha Inox 6AN / AN6', 'soquete torneado CP16 wire wrap 17,9 mm 16 pinos', 'Bateria lipo 2200mAh 11.1V 30C 3S']
        tipo_produto_compras.append(tipos[index])

    if binario == 2:
        sub_adm = random.choice(['Marketing', 'Recursos Humanos', 'Captação de Recursos'])
        subssistemas_compras.append(sub_adm)

        codigos = ['KS20391', 'KS20302', 'K9L0.99', 'K9L0.99', 'K9M1.901', 'CX50.10', 'T3T4.R3V', 'KAO30O', 'KAO2349.1', '99.1992', 'LS492.12', 'N2C8.8', 'M9999.19', 'KLDJSU88', '1293.AIX', 'X1X0SA0X.1']
        codigo_escolhido = random.choice(codigos)
        codigo_compras.append(codigo_escolhido)
        index = codigos.index(codigo_escolhido)

        tipos = ['Caneta esferográfica', 'Tinta para impressora Magenta', 'Tinta para impressora Ciano', 'Tinta para impressora Amarela', 'Tinta para impressora Preta', 'Post-It', 'Durex', 'Taxinhas para quadro', 'Folhas de Papel Sulfite 500 (resma)', 'Lápis HB', 'Pincel Atômico Azul', 'Pincel Atômico Preto', 'Marcador Permanente Rosa', 'Mousepad', 'Teclado', 'Mouse']
        tipo_produto_compras.append(tipos[index])


# parafusos
subssistemas_compras[9], tipo_produto_compras[9], codigo_compras[9] = 'Motor e Transmissão', 'Parafuso', 'M10CR8.8'
subssistemas_compras[18], tipo_produto_compras[18], codigo_compras[18] = 'Eletrônica', 'Parafuso', 'M4CR8.8'
subssistemas_compras[21], tipo_produto_compras[21], codigo_compras[21] = 'Eletrônica', 'Parafuso', 'M10CR8.8'
subssistemas_compras[25], tipo_produto_compras[25], codigo_compras[25] = 'Simulação', 'Parafuso', 'M10CR8.8'
subssistemas_compras[39], tipo_produto_compras[39], codigo_compras[39] = 'Eletrônica', 'Parafuso', 'M2CR8.8'
subssistemas_compras[49], tipo_produto_compras[49], codigo_compras[49] = 'Freio', 'Parafuso', 'M2CR8.8'
subssistemas_compras[50], tipo_produto_compras[50], codigo_compras[50] = 'Eletrônica', 'Parafuso', 'M2CR12.9'
subssistemas_compras[65], tipo_produto_compras[65], codigo_compras[65] = 'Freio', 'Parafuso', 'M10CR8.8'
subssistemas_compras[66], tipo_produto_compras[66], codigo_compras[66] = 'Motor e Transmissão', 'Parafuso', 'M2CR12.9'
subssistemas_compras[74], tipo_produto_compras[74], codigo_compras[74] = 'Suspensão e Direção', 'Parafuso', 'M8CR12.9'
subssistemas_compras[90], tipo_produto_compras[90], codigo_compras[90] = 'Freio', 'Parafuso', 'M6CR12.9'
subssistemas_compras[95], tipo_produto_compras[95], codigo_compras[95] = 'Suspensão e Direção', 'Parafuso', 'M6CR12.9'

lista_compras = pd.DataFrame(data=({'Valor total': valor_compras, 'Subssistema solicitante': subssistemas_compras, 'Modalidade de aquisição': modo_compras, 'Quantidade a ser adquirida': quantidade_compras, 'Tipo do produto': tipo_produto_compras, 'Código universal do produto': codigo_compras}))
lista_compras.to_excel('lista_compras.xlsx', index = False)
lista_compras
# Out:
#     Valor total Subssistema solicitante Modalidade de aquisição  \
# 0         49.16               Simulação   Fornecedor específico
# 1         36.25        Recursos Humanos     Qualquer fornecedor
# 2         78.69     Motor e Transmissão   Fornecedor específico
# 3        111.78        Recursos Humanos   Fornecedor específico
# 4         73.32    Captação de Recursos   Fornecedor específico
# ..          ...                     ...                     ...
# 95        58.42     Suspensão e Direção     Qualquer fornecedor
# 96       122.83              Eletrônica   Fornecedor específico
# 97       164.11    Captação de Recursos     Qualquer fornecedor
# 98       195.42               Marketing     Qualquer fornecedor
# 99        36.72        Recursos Humanos     Qualquer fornecedor
#
#     Quantidade a ser adquirida  \
# 0                            2
# 1                            1
# 2                            1
# 3                            1
# 4                            3
# ...

# %%
repetidos = []
matriculas_cadastro = []
nomes_cadastro = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônio', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis', 'Fernando', 'Fabio', 'Roberto', 'Márcio', 'Edson', 'André', 'Sérgio', 'Josefa', 'Patrícia', 'Daniel', 'Rodrigo', 'Rafael', 'Joaquim', 'Vera', 'Ricardo', 'Eduardo', 'Terezinha', 'Sônia', 'Alexandre', 'Rita', 'Luciana', 'Cláudio', 'Rosa', 'Benedito', 'Leandro', 'Raimunda', 'Mário']
cargos_cadastro = []
subssistemas_cadastro = []
cargos_subs_cadastro = []

for i in range(8):
    subssistemas_cadastro.append('Chassi')
    subssistemas_cadastro.append('Freio')
for i in range(6):
    subssistemas_cadastro.append('Eletrônica')
    subssistemas_cadastro.append('Motor e Transmissão')
    subssistemas_cadastro.append('Simulação')
    subssistemas_cadastro.append('Suspensão e Direção')
for i in range(2):
    subssistemas_cadastro.append('Captação de Recursos')
    subssistemas_cadastro.append('Marketing')
for i in range(3):
    subssistemas_cadastro.append('Recursos Humanos')
    subssistemas_cadastro.append('-')

for i in range(50):
    cargos_cadastro.append('Membro')
cargos_cadastro[45], cargos_cadastro[47], cargos_cadastro[49] = 'Capitã(o)', 'Diretor(a) de Projetos', 'Diretor(a) de Administrativo'
cargos_cadastro[0], cargos_cadastro[1], cargos_cadastro[16], cargos_cadastro[17], cargos_cadastro[18], cargos_cadastro[19], cargos_cadastro[40], cargos_cadastro[41], cargos_cadastro[44] = 'Gerente', 'Gerente', 'Gerente', 'Gerente', 'Gerente', 'Gerente', 'Gerente', 'Gerente', 'Gerente'

for i in range(len(cargos_cadastro)):
    cargos_subs_cadastro.append([cargos_cadastro[i], subssistemas_cadastro[i]])
tmp = list(zip(nomes_cadastro, cargos_subs_cadastro))
random.shuffle(tmp)
nomes_cadastro, cargos_subs_cadastro = zip(*tmp)
cargos_cadastro, subssistemas_cadastro = [], []
for dupla in cargos_subs_cadastro:
    cargos_cadastro.append(dupla[0])
    subssistemas_cadastro.append(dupla[1])

matriculaBase = '216150'
for i in range(len(nomes_cadastro)):
    alg1 = str(random.randint(0,9))
    alg2 = str(random.randint(0,9))
    while (alg1+alg2) in repetidos:
        alg1 = str(random.randint(0,9))
        alg2 = str(random.randint(0,9))    
    if (alg1+alg2) not in repetidos:
        repetidos.append(alg1+alg2)
        matriculas_cadastro.append(int(matriculaBase+alg1+alg2))

cadastro_membros = pd.DataFrame(data=({'Matrícula': matriculas_cadastro, 'Nome': nomes_cadastro, 'Cargo': cargos_cadastro, 'Sub-sistema': subssistemas_cadastro}))
cadastro_membros.to_excel('cadastro_membros.xlsx', index = False)
cadastro_membros
# Out:
#     Matrícula       Nome                         Cargo           Sub-sistema
# 0    21615006     Daniel                        Membro            Eletrônica
# 1    21615036   Raimundo                        Membro                 Freio
# 2    21615058      Mário  Diretor(a) de Administrativo                     -
# 3    21615089    Antônio                        Membro                 Freio
# 4    21615073    Antônio                        Membro                Chassi
# 5    21615007   Benedito                        Membro      Recursos Humanos
# 6    21615075    Ricardo                        Membro   Motor e Transmissão
# 7    21615044     Márcia                       Gerente             Simulação
# 8    21615045       Luiz                        Membro                Chassi
# 9    21615063      Paulo                        Membro                 Freio
# 10   21615028       José                       Gerente                 Freio
# ...

# %%
tipo_porta = []
subssistemas_porta = []
qrcode_porta = []
matriculas_porta = []
horarios_porta = []
os_3_escolhidos = []
os_3_horario_chegada = []
os_3_horario_saida = []

so_eletronica, so_freio, so_susp, so_simulacao, so_chassi, so_RH, so_MKT, so_capt = [], [], [], [], [], [], [], []


indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Eletrônica']
for index in indices:
    so_eletronica.append(matriculas_cadastro[index])

indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Recursos Humanos']
for index in indices:
    so_RH.append(matriculas_cadastro[index])
    
indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Marketing']
for index in indices:
    so_MKT.append(matriculas_cadastro[index])
    
indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Captação de Recursos']
for index in indices:
    so_capt.append(matriculas_cadastro[index])
    
indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Simulação']
for index in indices:
    so_simulacao.append(matriculas_cadastro[index])
    
indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Suspensão e Direção']
for index in indices:
    so_susp.append(matriculas_cadastro[index])
    
indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Chassi']
for index in indices:
    so_chassi.append(matriculas_cadastro[index])
        
indices = [index for index, element in enumerate(subssistemas_cadastro) if element == 'Freio']
for index in indices:
    so_freio.append(matriculas_cadastro[index])


i = 0
for pessoa in so_freio:
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    subssistemas_porta.append('Freio')
    subssistemas_porta.append('Freio')
    matriculas_porta.append(pessoa)
    matriculas_porta.append(pessoa)
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')

    if i <= 2:
        hora_entrada = random.randint(7,15)
        if len(str(hora_entrada)) == 1:
            hora_entrada = '0' + str(hora_entrada)
        minuto_entrada = random.randint(0,59)
        if len(str(minuto_entrada)) == 1:
            minuto_entrada = '0' + str(minuto_entrada)
        segundo_entrada = random.randint(0,59)
        if len(str(segundo_entrada)) == 1:
            segundo_entrada = '0' + str(segundo_entrada)
        horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
        hora_saida = random.randint(16,20)
        if len(str(hora_saida)) == 1:
            hora_saida = '0' + str(hora_saida)
        minuto_saida = random.randint(0,59)
        if len(str(minuto_saida)) == 1:
            minuto_saida = '0' + str(minuto_saida)
        segundo_saida = random.randint(0,59)
        if len(str(segundo_saida)) == 1:
            segundo_saida = '0' + str(segundo_saida)
        horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')
        os_3_escolhidos.append(pessoa)
        os_3_horario_chegada.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
        os_3_horario_saida.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')

    if i > 2:
        hora_entrada = random.randint(7,11)
        if len(str(hora_entrada)) == 1:
            hora_entrada = '0' + str(hora_entrada)
        minuto_entrada = random.randint(0,59)
        if len(str(minuto_entrada)) == 1:
            minuto_entrada = '0' + str(minuto_entrada)
        segundo_entrada = random.randint(0,59)
        if len(str(segundo_entrada)) == 1:
            segundo_entrada = '0' + str(segundo_entrada)
        horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
        hora_saida = random.randint(12,15)
        if len(str(hora_saida)) == 1:
            hora_saida = '0' + str(hora_saida)
        minuto_saida = random.randint(0,59)
        if len(str(minuto_saida)) == 1:
            minuto_saida = '0' + str(minuto_saida)
        segundo_saida = random.randint(0,59)
        if len(str(segundo_saida)) == 1:
            segundo_saida = '0' + str(segundo_saida)
        horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')

    i += 1
    
for matricula in so_eletronica:
    subssistemas_porta.append('Eletrônica')
    subssistemas_porta.append('Eletrônica')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    matriculas_porta.append(matricula)
    matriculas_porta.append(matricula)
    hora_entrada = random.randint(7,12)
    if len(str(hora_entrada)) == 1:
        hora_entrada = '0' + str(hora_entrada)
    minuto_entrada = random.randint(0,59)
    if len(str(minuto_entrada)) == 1:
        minuto_entrada = '0' + str(minuto_entrada)
    segundo_entrada = random.randint(0,59)
    if len(str(segundo_entrada)) == 1:
        segundo_entrada = '0' + str(segundo_entrada)
    horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
    hora_saida = random.randint(13,20)
    if len(str(hora_saida)) == 1:
        hora_saida = '0' + str(hora_saida)
    minuto_saida = random.randint(0,59)
    if len(str(minuto_saida)) == 1:
        minuto_saida = '0' + str(minuto_saida)
    segundo_saida = random.randint(0,59)
    if len(str(segundo_saida)) == 1:
        segundo_saida = '0' + str(segundo_saida)
    horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')
forever_RH = []
for matricula in so_RH:
    subssistemas_porta.append('Recursos Humanos')
    subssistemas_porta.append('Recursos Humanos')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    matriculas_porta.append(matricula)
    matriculas_porta.append(matricula)
    hora_entrada = random.randint(7,12)
    if len(str(hora_entrada)) == 1:
        hora_entrada = '0' + str(hora_entrada)
    minuto_entrada = random.randint(0,59)
    if len(str(minuto_entrada)) == 1:
        minuto_entrada = '0' + str(minuto_entrada)
    segundo_entrada = random.randint(0,59)
    if len(str(segundo_entrada)) == 1:
        segundo_entrada = '0' + str(segundo_entrada)
    horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
    hora_saida = random.randint(13,20)
    if len(str(hora_saida)) == 1:
        hora_saida = '0' + str(hora_saida)
    minuto_saida = random.randint(0,59)
    if len(str(minuto_saida)) == 1:
        minuto_saida = '0' + str(minuto_saida)
    segundo_saida = random.randint(0,59)
    if len(str(segundo_saida)) == 1:
        segundo_saida = '0' + str(segundo_saida)
    horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')
    forever_RH.append(matricula)
forever_MKT = []
for matricula in so_MKT:
    subssistemas_porta.append('Marketing')
    subssistemas_porta.append('Marketing')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    matriculas_porta.append(matricula)
    matriculas_porta.append(matricula)
    hora_entrada = random.randint(7,12)
    if len(str(hora_entrada)) == 1:
        hora_entrada = '0' + str(hora_entrada)
    minuto_entrada = random.randint(0,59)
    if len(str(minuto_entrada)) == 1:
        minuto_entrada = '0' + str(minuto_entrada)
    segundo_entrada = random.randint(0,59)
    if len(str(segundo_entrada)) == 1:
        segundo_entrada = '0' + str(segundo_entrada)
    horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
    hora_saida = random.randint(13,20)
    if len(str(hora_saida)) == 1:
        hora_saida = '0' + str(hora_saida)
    minuto_saida = random.randint(0,59)
    if len(str(minuto_saida)) == 1:
        minuto_saida = '0' + str(minuto_saida)
    segundo_saida = random.randint(0,59)
    if len(str(segundo_saida)) == 1:
        segundo_saida = '0' + str(segundo_saida)
    horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')
    forever_MKT.append(matricula)
forever_capt = []

for matricula in so_capt:
    subssistemas_porta.append('Captação de Recursos')
    subssistemas_porta.append('Captação de Recursos')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    matriculas_porta.append(matricula)
    matriculas_porta.append(matricula)
    hora_entrada = random.randint(7,12)
    if len(str(hora_entrada)) == 1:
        hora_entrada = '0' + str(hora_entrada)
    minuto_entrada = random.randint(0,59)
    if len(str(minuto_entrada)) == 1:
        minuto_entrada = '0' + str(minuto_entrada)
    segundo_entrada = random.randint(0,59)
    if len(str(segundo_entrada)) == 1:
        segundo_entrada = '0' + str(segundo_entrada)
    horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
    hora_saida = random.randint(13,20)
    if len(str(hora_saida)) == 1:
        hora_saida = '0' + str(hora_saida)
    minuto_saida = random.randint(0,59)
    if len(str(minuto_saida)) == 1:
        minuto_saida = '0' + str(minuto_saida)
    segundo_saida = random.randint(0,59)
    if len(str(segundo_saida)) == 1:
        segundo_saida = '0' + str(segundo_saida)
    horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')
    forever_capt.append(matricula)
    print(matricula)

for matricula in so_simulacao:
    subssistemas_porta.append('Simulação')
    subssistemas_porta.append('Simulação')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    matriculas_porta.append(matricula)
    matriculas_porta.append(matricula)
    hora_entrada = random.randint(7,12)
    if len(str(hora_entrada)) == 1:
        hora_entrada = '0' + str(hora_entrada)
    minuto_entrada = random.randint(0,59)
    if len(str(minuto_entrada)) == 1:
        minuto_entrada = '0' + str(minuto_entrada)
    segundo_entrada = random.randint(0,59)
    if len(str(segundo_entrada)) == 1:
        segundo_entrada = '0' + str(segundo_entrada)
    horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
    hora_saida = random.randint(13,20)
    if len(str(hora_saida)) == 1:
        hora_saida = '0' + str(hora_saida)
    minuto_saida = random.randint(0,59)
    if len(str(minuto_saida)) == 1:
        minuto_saida = '0' + str(minuto_saida)
    segundo_saida = random.randint(0,59)
    if len(str(segundo_saida)) == 1:
        segundo_saida = '0' + str(segundo_saida)
    horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')

for matricula in so_susp:
    subssistemas_porta.append('Suspensão e Direção')
    subssistemas_porta.append('Suspensão e Direção')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    matriculas_porta.append(matricula)
    matriculas_porta.append(matricula)
    hora_entrada = random.randint(7,12)
    if len(str(hora_entrada)) == 1:
        hora_entrada = '0' + str(hora_entrada)
    minuto_entrada = random.randint(0,59)
    if len(str(minuto_entrada)) == 1:
        minuto_entrada = '0' + str(minuto_entrada)
    segundo_entrada = random.randint(0,59)
    if len(str(segundo_entrada)) == 1:
        segundo_entrada = '0' + str(segundo_entrada)
    horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
    hora_saida = random.randint(13,20)
    if len(str(hora_saida)) == 1:
        hora_saida = '0' + str(hora_saida)
    minuto_saida = random.randint(0,59)
    if len(str(minuto_saida)) == 1:
        minuto_saida = '0' + str(minuto_saida)
    segundo_saida = random.randint(0,59)
    if len(str(segundo_saida)) == 1:
        segundo_saida = '0' + str(segundo_saida)
    horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')
print(so_chassi)
for matricula in so_chassi:
    subssistemas_porta.append('Chassi')
    subssistemas_porta.append('Chassi')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    qrcode_porta.append(f'{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}{random.randint(0,9)}')
    tipo_porta.append('entrada')
    tipo_porta.append('saída')
    matriculas_porta.append(matricula)
    matriculas_porta.append(matricula)
    hora_entrada = random.randint(7,12)
    if len(str(hora_entrada)) == 1:
        hora_entrada = '0' + str(hora_entrada)
    minuto_entrada = random.randint(0,59)
    if len(str(minuto_entrada)) == 1:
        minuto_entrada = '0' + str(minuto_entrada)
    segundo_entrada = random.randint(0,59)
    if len(str(segundo_entrada)) == 1:
        segundo_entrada = '0' + str(segundo_entrada)
    horarios_porta.append(f'{hora_entrada}:{minuto_entrada}:{segundo_entrada}')
    hora_saida = random.randint(13,20)
    if len(str(hora_saida)) == 1:
        hora_saida = '0' + str(hora_saida)
    minuto_saida = random.randint(0,59)
    if len(str(minuto_saida)) == 1:
        minuto_saida = '0' + str(minuto_saida)
    segundo_saida = random.randint(0,59)
    if len(str(segundo_saida)) == 1:
        segundo_saida = '0' + str(segundo_saida)
    horarios_porta.append(f'{hora_saida}:{minuto_saida}:{segundo_saida}')

tudo_junto = []
for i in range(len(tipo_porta)):
    tudo_junto.append([subssistemas_porta[i], qrcode_porta[i], matriculas_porta[i], horarios_porta[i]])

tmp = list(zip(tipo_porta, tudo_junto))
random.shuffle(tmp)
tipo_porta, tudo_junto = zip(*tmp)
subssistemas_porta, qrcode_porta, matriculas_porta, horarios_porta = [], [], [], []
for quarteto in tudo_junto:
    subssistemas_porta.append(quarteto[0])
    qrcode_porta.append(quarteto[1])
    matriculas_porta.append(quarteto[2])
    horarios_porta.append(quarteto[3])

logs_porta = pd.DataFrame(data=({'Tipo de acesso': tipo_porta, 'Subssistema do membro': subssistemas_porta, 'Código correspondente ao QR Code': qrcode_porta}))
logs_porta.to_excel('logs_porta.xlsx', index = False)
logs_porta
# Out:
# 21615046
# 21615027
# [21615073, 21615045, 21615094, 21615016, 21615014, 21615025, 21615054, 21615032]
#    Tipo de acesso Subssistema do membro Código correspondente ao QR Code
# 0         entrada             Simulação                           415640
# 1         entrada            Eletrônica                           537644
# 2           saída                Chassi                           400897
# 3           saída            Eletrônica                           358164
# 4           saída                Chassi                           616881
# ..            ...                   ...                              ...
# 77        entrada             Marketing                           929969
# 78        entrada      Recursos Humanos                           225986
# 79          saída   Suspensão e Direção                           887080
# 80          saída  Captação de Recursos                           500462
# ...

# %%
logs_porta_c_horario = pd.DataFrame(data=({'Tipo de acesso': tipo_porta, 'Matrícula do membro': matriculas_porta, 'Código correspondente ao QR Code': qrcode_porta, 'Horário': horarios_porta}))
logs_porta_c_horario.to_excel('logs_porta_c_horario.xlsx', index = False)
logs_porta_c_horario
# Out:
#    Tipo de acesso  Matrícula do membro Código correspondente ao QR Code  \
# 0         entrada             21615044                           415640
# 1         entrada             21615006                           537644
# 2           saída             21615014                           400897
# 3           saída             21615004                           358164
# 4           saída             21615032                           616881
# ..            ...                  ...                              ...
# 77        entrada             21615043                           929969
# 78        entrada             21615059                           225986
# 79          saída             21615067                           887080
# 80          saída             21615046                           500462
# 81          saída             21615036                           439043
#
#      Horário
# 0   10:01:52
# 1   11:39:20
# 2   15:49:39
# 3   19:48:05
# 4   19:28:36
# ..       ...
# ...

# %%
posts_bajanews = []
subssistemas_atividade_bajanews = []
subssistemas_bajanews = []
atividade_bajanews = []


for rede in ['Facebook', 'Instagram', 'WhatsApp', 'LinkedIn']:
    for i in range(9):
        posts_bajanews.append(rede)
    subssistemas_atividade_bajanews.append(['Suspensão e Direção', 'Fala galera, Tomás gerente de suspensão aqui! Nessa semana, a gente mexeu no carro. O nosso sub cuidou da montagem da suspensão nos quatro cantos do carro para conseguir colocar ele no chão e avaliar a geometria. Então pra isso precisamos usar alguns parafusos da oficina para montar nessa semana, também fizemos o pedido para parafusos novos para os testes e pra competição.'])
    subssistemas_atividade_bajanews.append(['Simulação', 'Eai pessoal, nessa semana o sub de simulaçao realizou a analise estrutural em FEM do braço superior da suspensão dianteita com base em uma simulaçao multicorpos como metodo de extraçao de forças.'])
    subssistemas_atividade_bajanews.append(['Motor e Transmissão', 'Fala galera, Parnes gerente de motor e transmissão aqui, essa semana a gente mexeu no carro, no caso, finalizou a usinagem da capa traseira da CR e já limamos o rasgo para a instalação do cordão o-ring, agora precisamos testar a vedação fechando a capa, instalando os parafusos e as porcas autotravantes'])
    subssistemas_atividade_bajanews.append(['Chassi', 'Fala galera tudo bem? Eu sou o gerente de chassi e vou falar o q a gente mexeu no carro nesta semana. Nosso sub focou em finalizar as carenagens, entao a gente terminou de soldar todas as tabs para fazer a fixação delas, utilizamos todos os cortes e prendemos com os parafusos no carro. Alem disso a gente soldou 2 tabs para entregar para eletronica e colaboramos pra fazer o posicionamento da linha de freio'])
    subssistemas_atividade_bajanews.append(['Eletrônica', 'Oi gente, sub de eletrônica aqui. Nessa semana focamos em produzir a plaquinha pro painel em conjuto com a produção do codigo para fazer com que os leds acendam, por exemplo, o display de 7 segmentos para velocidade e do tanque da gasolina.']) # eletronica
    subssistemas_atividade_bajanews.append(['Freio', 'Fala galera tudo bom? Aqui é o Léo gerente de freio e nessa semana, a gente mexeu no carro. Nosso subsistema teve como objetivo checar a montagem dos pedais no carro. Querendo garantir q ao prende-los nas tabs, utilizando parafusos e arruelas de nylon, não haja qualquer jogo lateral do pedal. Tivemos também que checar o curso do pedal do acelerador, isso sendo feito ao ajustar os parafusos que servem como fim de curso para permitir a melhor ergonomia possível para o piloto.']) # freio
    subssistemas_atividade_bajanews.append(['Captação de Recursos', 'Fala galera, Tess aqui. Nessa semana em captação nós entramos em contato com os patrocinadores e trabalhamos no Business Plan para a competição! Abraço em todos!']) # captacao
    subssistemas_atividade_bajanews.append(['Recursos Humanos', 'Fala time, belezinha? Gemha do RH falando. Nesta semana, colocamos em prática a nova implementação da 2a fase do Processo Seletivo 2022/1. Espero que todos gostem do resultado dela! Se quiserem sugerir algo, entrem em contato comigo!']) # rh
    subssistemas_atividade_bajanews.append(['Marketing', 'Nessa semana o subsistema de marketing planejou nosso calendário de post para as próximas 3 semana, e começamos a ver se há interesse da equipe em produzir um kit jogos para o regional.']) # marketing


tmp = list(zip(posts_bajanews, subssistemas_atividade_bajanews))
random.shuffle(tmp)
posts_bajanews, subssistemas_atividade_bajanews = zip(*tmp)

for dupla in subssistemas_atividade_bajanews:
    subssistemas_bajanews.append(dupla[0])
    atividade_bajanews.append(dupla[1])

baja_news = pd.DataFrame(data=({'Subssistema do post': subssistemas_bajanews, 'Rede social postada': posts_bajanews, 'O que fizemos': atividade_bajanews}))
baja_news.to_excel('baja_news.xlsx', index = False)
baja_news
# Out:
#      Subssistema do post Rede social postada  \
# 0    Suspensão e Direção            WhatsApp
# 1                  Freio           Instagram
# 2              Marketing            WhatsApp
# 3              Simulação            WhatsApp
# 4    Motor e Transmissão            WhatsApp
# 5              Marketing           Instagram
# 6   Captação de Recursos           Instagram
# 7    Suspensão e Direção            LinkedIn
# 8                  Freio            WhatsApp
# 9    Motor e Transmissão           Instagram
# 10             Simulação            LinkedIn
# 11  Captação de Recursos            WhatsApp
# 12      Recursos Humanos            WhatsApp
# 13             Marketing            Facebook
# 14   Suspensão e Direção            Facebook
# 15   Suspensão e Direção           Instagram
# 16            Eletrônica            WhatsApp
# 17      Recursos Humanos           Instagram
# 18                Chassi           Instagram
# 19            Eletrônica           Instagram
# ...

# %%
item_retirada = []
quantidade_retirada = []
matricula_retirada = []

so_freio, so_adm = [], []
for i in range(len(subssistemas_cadastro)):
    sub = subssistemas_cadastro[i]
    if sub == 'Freio':
        so_freio.append(matriculas_cadastro[i])
    if sub in ['Recursos Humanos', 'Marketing', 'Captação de Recursos']:
        so_adm.append(matriculas_cadastro[i])
shuffler = []
for i in range(3):    
    for matricula in so_adm:
        quantidade_retirada.append(random.randint(1,3))
        shuffler.append([random.choice(['Caneta esferográfica', 'Tinta para impressora Magenta', 'Tinta para impressora Ciano', 'Tinta para impressora Amarela', 'Tinta para impressora Preta', 'Post-It', 'Durex', 'Taxinhas para quadro', 'Folhas de Papel Sulfite 500 (resma)', 'Lápis HB', 'Pincel Atômico Azul', 'Pincel Atômico Preto', 'Marcador Permanente Rosa', 'Mousepad', 'Teclado', 'Mouse']), matricula])
quantidade_retirada.append(random.randint(1,3))
shuffler.append([random.choice(['Caneta esferográfica', 'Tinta para impressora Magenta', 'Tinta para impressora Ciano', 'Tinta para impressora Amarela', 'Tinta para impressora Preta', 'Post-It', 'Durex', 'Taxinhas para quadro', 'Folhas de Papel Sulfite 500 (resma)', 'Lápis HB', 'Pincel Atômico Azul', 'Pincel Atômico Preto', 'Marcador Permanente Rosa', 'Mousepad', 'Teclado', 'Mouse']), matricula])
for matricula in so_freio:
    quantidade_retirada.append(1)
    shuffler.append(['Parafuso', matricula])

tmp = list(zip(shuffler, quantidade_retirada))
random.shuffle(tmp)
shuffler, quantidade_retirada = zip(*tmp)
for dupla in shuffler:
    item_retirada.append(dupla[0])
    matricula_retirada.append(dupla[1])

registro_retirada_inventario = pd.DataFrame(data=({'Quantidade retirada': quantidade_retirada, 'Matrícula efetuante da retirada': matricula_retirada, 'Item retirado': item_retirada}))
registro_retirada_inventario.to_excel('registro_retirada_inventario.xlsx', index = False)
registro_retirada_inventario
# Out:
#     Quantidade retirada  Matrícula efetuante da retirada  \
# 0                     3                         21615007
# 1                     1                         21615036
# 2                     3                         21615081
# 3                     3                         21615043
# 4                     1                         21615043
# 5                     1                         21615089
# 6                     1                         21615007
# 7                     1                         21615043
# 8                     2                         21615020
# 9                     1                         21615088
# 10                    3                         21615081
# 11                    2                         21615046
# 12                    2                         21615059
# 13                    1                         21615028
# 14                    2                         21615081
# ...

# %%
numeros_pc = []
matricula_pc = []
horariosLogin_pc = []
horariosLogoff_pc = []
print(f'Culpado: {nomes_cadastro[matriculas_cadastro.index(os_3_escolhidos[0])]}')

#culpado
numeros_pc.append(random.randint(1,4))
matricula_pc.append(os_3_escolhidos[0])
horariosLogin_pc.append(os_3_horario_chegada[0])
saida = os_3_horario_saida[0]
saida = f'{int(saida[:2]) - 2}:{saida[3:]}'
horariosLogoff_pc.append(saida)


usando_pc = [os_3_escolhidos[1], os_3_escolhidos[2]]
i = 1

for os in usando_pc:
    numeros_pc.append(random.randint(1,4))
    matricula_pc.append(os)
    horariosLogin_pc.append(os_3_horario_chegada[i])
    horariosLogoff_pc.append(os_3_horario_saida[i])
    i += 1

for os in forever_MKT:
    numeros_pc.append(random.randint(1,4))
    matricula_pc.append(os)
    indices = [index for index, element in enumerate(matriculas_porta) if element == os]
    tmp = []
    for index in indices:
        tmp.append(horarios_porta[index])
    if int(tmp[0][:2]) < int(tmp[1][:2]):
        chegada = tmp[0]
        saida = tmp[1]
    if int(tmp[0][:2]) > int(tmp[1][:2]):
        chegada = tmp[1]
        saida = tmp[0]
    if int(saida[3:5]) < 2:
         saida = f'{int(saida[:1]) - 1}:{58}{saida[5:]}'
    if int(saida[3:5]) >= 2:
        saida = f'{saida[:3]}{int(saida[3:5]) - 2}{saida[5:]}'
    horariosLogin_pc.append(chegada)
    horariosLogoff_pc.append(saida)

for os in forever_RH:
    numeros_pc.append(random.randint(1,4))
    matricula_pc.append(os)
    indices = [index for index, element in enumerate(matriculas_porta) if element == os]
    tmp = []
    for index in indices:
        tmp.append(horarios_porta[index])
    if int(tmp[0][:2]) < int(tmp[1][:2]):
        chegada = tmp[0]
        saida = tmp[1]
    if int(tmp[0][:2]) > int(tmp[1][:2]):
        chegada = tmp[1]
        saida = tmp[0]
    if int(saida[3:5]) < 2:
         saida = f'{int(saida[:1]) - 1}:{58}{saida[5:]}'
    if int(saida[3:5]) >= 2:
        saida = f'{saida[:3]}{int(saida[3:5]) - 2}{saida[5:]}'
    horariosLogin_pc.append(chegada)
    horariosLogoff_pc.append(saida)

for os in forever_capt:
    numeros_pc.append(random.randint(1,4))
    matricula_pc.append(os)
    indices = [index for index, element in enumerate(matriculas_porta) if element == os]
    tmp = []
    for index in indices:
        tmp.append(horarios_porta[index])
    if int(tmp[0][:2]) < int(tmp[1][:2]):
        chegada = tmp[0]
        saida = tmp[1]
    if int(tmp[0][:2]) > int(tmp[1][:2]):
        chegada = tmp[1]
        saida = tmp[0]
    if int(saida[3:5]) < 2:
        saida = f'{int(saida[:1]) - 1}:{58}{saida[5:]}'
    if int(saida[3:5]) >= 2:
        saida = f'{saida[:3]}{int(saida[3:5]) - 2}{saida[5:]}'
    horariosLogin_pc.append(chegada)
    horariosLogoff_pc.append(saida)

permanencia_no_PC = pd.DataFrame(data=({'Horário de saída': horariosLogoff_pc, 'Matrícula de quem usou o PC ininterruptamente': matricula_pc, 'Número de identificação do PC': numeros_pc, 'Horário de entrada': horariosLogin_pc}))
permanencia_no_PC.to_excel('permanencia_no_PC.xlsx', index = False)
permanencia_no_PC
# Out:
# Culpado: Raimundo
#   Horário de saída  Matrícula de quem usou o PC ininterruptamente  \
# 0         19:24:33                                       21615036
# 1         20:19:54                                       21615089
# 2          16:7:43                                       21615063
# 3          16:7:12                                       21615043
# 4         13:22:34                                       21615081
# 5         13:19:58                                       21615007
# 6         20:46:34                                       21615059
# 7         13:36:59                                       21615020
# 8         17:33:08                                       21615046
# 9         18:14:31                                       21615027
#
#    Número de identificação do PC Horário de entrada
# 0                              2           13:52:02
# 1                              1           10:22:27
# 2                              1           08:07:42
# ...

# %%
tipo_geral = []
codigo_geral = [] #(M4CR8.8, M10CR8.8, M2CR12.9)
quantidade_geral = []

for parafuso in ['M4CR8.8', 'M10CR8.8', 'M2CR12.9']:
    quantidade_geral.append(random.randint(1,6))
    codigo_geral.append(parafuso)
    tipo_geral.append('Parafuso')

codigos = ['NM1029.1', 'N9.10MF', 'K930KL1.1', 'R7HT.1', 'DFSA0DF.5', 'DSD94455', 'DASIDJE3.3', '12321SJKJ', '2LMSOAMSI.1', 'XO0WE2M.2', '1203.12234', 'ASDW343.12', 'KASDI0.1', 'QWE.01231A', 'ASDKL.1023', 'PB9BF0.S1', 'LL123.492', 'DSA.1120', 'KLA1D.AS1']
tipos = ['ABRACADEIRA DE NYLON 3.6 X 200 BRANCA', 'ABRACADEIRA DE NYLON 4.8 X 200 T50R', 'Cordão O-ring espaguete de vedação de borracha de 10m', 'Tela metálica inoxidável malha 3mm,	fio1.6mm', 'Martelo com ponta de borracha', 'Cubo V3 Usinado', 'Sensor de temperatura DS18B20 à prova dagua - o modelo não deve divergir do link de referência', 'Modulo RF LORA - 433MHz - Módulo Wifi LoRa E32-TTL-100 NÃO PODE DIVERGIR DO MODELO DE REFERÊNCIA', 'Circuito integrado 74HC595 DIP - Shift Register -  NÃO COMPRAR SMD', 'Placa de fibra de vidro virgem cobread 20cm x 20cm', 'Óculos SAE SF300', 'Extintor capacidade extintora 1-A, 5-B, C de massa 1kg', 'Restritor de braço com especificação SFI 3.3', 'Saco Zip Lock 24 x 17 - N8', 'Manta silicone 3mm', 'Óleo para transmissão SAE 80W90 Motul/Lubrax/Mobil', 'Mangueira Aeroquip com Malha Inox 6AN / AN6', 'soquete torneado CP16 wire wrap 17,9 mm 16 pinos', 'Bateria lipo 2200mAh 11.1V 30C 3S']
for i in range(len(tipos)):
    quantidade_geral.append(random.randint(3,6))
    codigo_geral.append(codigos[i])
    tipo_geral.append(tipos[i])

tmp = list(zip(codigo_geral, tipo_geral))
random.shuffle(tmp)
codigo_geral, tipo_geral = zip(*tmp)

inventario_geral = pd.DataFrame(data=({'Código universal do produto': codigo_geral, 'Quantidade em estoque': quantidade_geral, 'Tipo de produto': tipo_geral}))
inventario_geral.to_excel('inventario_geral.xlsx', index = False)
inventario_geral
# Out:
#    Código universal do produto  Quantidade em estoque  \
# 0                   ASDW343.12                      1
# 1                   QWE.01231A                      3
# 2                   ASDKL.1023                      2
# 3                    DFSA0DF.5                      5
# 4                     M10CR8.8                      6
# 5                    12321SJKJ                      5
# 6                    XO0WE2M.2                      3
# 7                  2LMSOAMSI.1                      5
# 8                     DSA.1120                      6
# 9                     DSD94455                      3
# 10                  DASIDJE3.3                      6
# 11                    M2CR12.9                      5
# 12                   PB9BF0.S1                      3
# 13                  1203.12234                      6
# 14                     N9.10MF                      5
# 15                      R7HT.1                      4
# ...

# %%
# 'M4CR8.8', 'M10CR8.8', 'M2CR12.9'

# descricao_montagem = pd.DataFrame(data=({'Código universal do produto': codigo_geral, 'Quantidade em estoque': quantidade_geral, 'Tipo de produto': tipo_geral}))
# descricao_montagem.to_excel('descricao_montagem.xlsx', index = False)
# descricao_montagem
